# %%
#how age affects insurance cost

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
#load the data from the insurance.csv file
df = pd.read_csv('insurance.csv')

# %%
#plot a scatter plot of age vs charges
#plt.figure()
plt.scatter(df['age'],df['charges'])
plt.xlabel('Age')
plt.ylabel('Charges')
# Out:
# Text(0, 0.5, 'Charges')

# %%
#Fit a linear regression model to the data
linreg_model = LinearRegression()
#x = df['age'].values.reshape(-1,1)
#y = df['charges'].values
x = df[['age']]
y = df['charges']
linreg_model.fit(x,y)
# Out:
# LinearRegression()

# %%
# make predictions on the input data
#y_pred = linreg_model.predict(x)

# %%
#plot the best fit line
#plt.plot(x,y_pred, color="red")
plt.plot(x,linreg_model.predict(x),color='red')

# %%
#show the plot
plt.show()
